# %%
from ocpa.objects.log.importer.ocel import factory as ocel_import_factory
from ocpa.algo.discovery.ocpn import algorithm as ocpn_discovery_factory
from ocpa.visualization.oc_petri_net import factory as ocpn_vis_factory

# %%
path = './ocel/ocpa/transfer_order.jsonocel'
ocel = ocel_import_factory.apply(path)
ocpn = ocpn_discovery_factory.apply(ocel, parameters={"debug": False})

gviz = ocpn_vis_factory.apply(ocpn)
ocpn_vis_factory.save(gviz, "./img/ocpn/ocpa/transfer_order.png")

ocpn_vis_factory.view(gviz)

# %%
path = './ocel/ocpa/recruiting.jsonocel'
ocel = ocel_import_factory.apply(path)
ocpn = ocpn_discovery_factory.apply(ocel, parameters={"debug": False})

gviz = ocpn_vis_factory.apply(ocpn)
ocpn_vis_factory.save(gviz, "./img/ocpn/ocpa/recruiting.png")

ocpn_vis_factory.view(gviz)
